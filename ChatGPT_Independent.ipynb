# %% [markdown]
# # ChatGPT Conversation

# %% [markdown]
# # Input

# %% [markdown]
# Hi ChatGPT, I’m working on my Week 6 Independent-led Lab for my graduate Python course (BGEN 632 - UM MSBA). The assignment In this assignment you will practice using collections for a student management system. This system will allow you to add students, view GPA metrics, and assign academic violations.
#
# I am not looking for final answers. I want help understanding how to approach the assignment step-by-step, especially using Boolean values to switch menu prompts, storing questions/responses in lists, and generating random responses from a list.
#
# Can you walk me through how I should structure the logic using pseudo-code or examples—without giving me the full solution? I’ll write my own code based on what I learn. Assignment: # Instructor-led Lab
# ## Collections: Grade Entry System
# ## Michelle Calderwood | 4.6.2025
#
# ##### In this assignment, we build a student management system using lists.
# ##### The program allows users to add students, track GPA metrics, and assign academic violations.
# ##### Note: I used ChatGPT for help in structuring this code.
# ###### Reference: https://chatgpt.com/share/67d9beee-4c38-8013-9c26-c83ee2257463
#
# import random as rand
#
# ## ---------------------------
# ## Section: Initial Data Setup
# ## ---------------------------
# first_names = ["Carmen", "Sydney", "Neil", "Marcus"]
# last_names = ["Berzatto", "Adamu", "Fak", "Brooks"]
# majors = ["Culinary Arts", "Business", "Engineering", "Psychology"]
# gpas = [3.2, 3.7, 2.9, 3.5]
# violations = [""] * 4
#
# violation_list = [
#     "Copying homework",
#     "Cheating on exam",
#     "Plagiarism",
#     "Cheating on quiz",
#     "Writing paper for another student"
# ]
#
# ## -----------------------------
# ## Section: Display Student Info
# ## -----------------------------
# def display_students():
#     print("\n--- Current Students ---")
#     for i in range(len(first_names)):
#         print(f"{i+1}. {first_names[i]} {last_names[i]} | Major: {majors[i]} | GPA: {gpas[i]} | Violation: {violations[i] if violations[i] else 'None'}")
#
# ## -----------------------------
# ## Section: GPA Metrics
# ## -----------------------------
# def query_gpa_metrics():
#     print("\n--- GPA Metrics ---")
#     print(f"Max GPA: {max(gpas):.2f}")
#     print(f"Min GPA: {min(gpas):.2f}")
#     print(f"Average GPA: {sum(gpas)/len(gpas):.2f}")
#
# ## -----------------------------
# ## Section: Add New Student
# ## -----------------------------
# def add_student():
#     first = input("Enter first name: ")
#     last = input("Enter last name: ")
#     major = input("Enter major: ")
#     while True:
#         try:
#             gpa = float(input("Enter GPA (0.0 - 4.0): "))
#             if 0.0 <= gpa <= 4.0:
#                 break
#             else:
#                 print("GPA must be between 0.0 and 4.0.")
#         except:
#             print("Invalid GPA. Try again.")
#     first_names.append(first)
#     last_names.append(last)
#     majors.append(major)
#     gpas.append(gpa)
#     violations.append("")
#     print(f"Student {first} {last} added successfully.\n")
#
# ## -----------------------------
# ## Section: Assign Violation
# ## -----------------------------
# def assign_violation():
#     display_students()
#     try:
#         idx = int(input("\nSelect a student by number: ")) - 1
#         if 0 <= idx < len(first_names):
#             print("\nSelect an academic violation:")
#             for i, v in enumerate(violation_list):
#                 print(f"{i+1}. {v}")
#             v_choice = int(input("Your choice: ")) - 1
#             if 0 <= v_choice < len(violation_list):
#                 violations[idx] = violation_list[v_choice]
#                 print(f"Violation assigned to {first_names[idx]} {last_names[idx]}.")
#             else:
#                 print("Invalid violation selected.")
#         else:
#             print("Invalid student selected.")
#     except:
#         print("Invalid input.")
#
# ## -----------------------------
# ## Section: Main Menu
# ## -----------------------------
# def run_menu():
#     while True:
#         print("\n========== Grade Entry System ==========")
#         print("1. Student Information Query")
#         print("2. Student Information Entry")
#         print("3. Query GPA Metrics")
#         print("4. Academic Violations")
#         print("5. Quit Program")
#         choice = input("Enter your choice (1-5): ")
#
#         if choice == "1":
#             display_students()
#         elif choice == "2":
#             add_student()
#         elif choice == "3":
#             query_gpa_metrics()
#         elif choice == "4":
#             assign_violation()
#         elif choice == "5":
#             print("Exiting program...")
#             break
#         else:
#             print("Invalid selection. Please try again.")

# %% [markdown]
# ## Output

# %% [markdown]
# Absolutely, Michelle! You’re asking all the right questions to build a solid foundation. Let’s break this Independent Lab down the same way we did for the Crystal Ball one—but tailored to a student management system using lists and collections. No final code—just a walkthrough of the logic and structure so you can build it with confidence.
#
# ⸻
#
# 🧩 Key Features of the Assignment
#
# You’re building a program that can:
# 	1.	Add students.
# 	2.	View GPA metrics (e.g., min, max, avg).
# 	3.	Assign academic violations.
# 	4.	Use menu logic to navigate those options.
# 	5.	Store all data in lists (not dictionaries or classes).
#
# ⸻
#
# 🧠 Step-by-Step Logic Plan (with Pseudocode)
#
# ⸻
#
# 1. Set Up Your Collections (Lists)
#
# Each student has:
# 	•	First Name
# 	•	Last Name
# 	•	Major
# 	•	GPA
# 	•	Violation (optional)
#
# You’ll need parallel lists like:
#
# first_names = []
# last_names = []
# majors = []
# gpas = []
# violations = []
#
# Each index across these lists represents the same student.
#
# ⸻
#
# 2. Display a Menu Until the User Quits
#
# Use a while True loop with a menu printed inside.
#
# while True:
#     print("1. View Students")
#     print("2. Add Student")
#     print("3. View GPA Metrics")
#     print("4. Assign Academic Violation")
#     print("5. Quit")
#
#     choice = input("Select an option: ")
#
#     if choice == "1":
#         display_students()
#     elif choice == "2":
#         add_student()
#     ...
#     elif choice == "5":
#         break
#
# This gives you a loop-driven command menu.
#
# ⸻
#
# 3. Add a Student
#
# Prompt for each piece of data (name, major, GPA). For GPA, use a loop to ensure it’s a float between 0.0 and 4.0.
#
# Append each item to the corresponding list.
#
# first_names.append(first_name)
# ...
# violations.append("")  # start blank
#
#
#
# ⸻
#
# 4. View Students
#
# Loop through all list indices and print student details using the same index across all lists:
#
# for i in range(len(first_names)):
#     print(f"{first_names[i]} {last_names[i]} | GPA: {gpas[i]}")
#
#
#
# ⸻
#
# 5. GPA Metrics
#
# Use built-in functions:
# 	•	max(gpas)
# 	•	min(gpas)
# 	•	sum(gpas) / len(gpas)
#
# Make sure gpas isn’t empty before doing math!
#
# ⸻
#
# 6. Assign Academic Violations
#
# Use another list of predefined violations:
#
# violation_list = [
#     "Copying homework",
#     "Cheating on exam",
#     ...
# ]
#
# Steps:
# 	1.	Show the current students with indexes.
# 	2.	Prompt user to select one by number.
# 	3.	Show violations and let user pick one.
# 	4.	Assign it using violations[selected_student_index] = chosen_violation
#
# Add checks for:
# 	•	valid student index
# 	•	valid violation choice
# 	•	try/except to prevent crashes
#
# ⸻
#
# 💡 Where Boolean Values Might Help
#
# If you want to track whether a student has already been added or if any violations exist, you can use flags like:
#
# has_students = len(first_names) > 0
# has_violations = any(v != "" for v in violations)
#
# Or:
#
# first_student_added = True
#
# Then you can change prompts or show warnings (e.g., “No students yet!”).
#
# ⸻
#
# ✅ Optional: Use random?
#
# You mentioned random, which isn’t required here—but if you want to randomly assign a violation as a fun feature:
#
# import random
# violations[i] = random.choice(violation_list)
#
#
#
# ⸻
#
# Summary
#
# Feature	Uses
# Add/View Students	Parallel lists
# GPA Calculations	max, min, sum
# Assign Violations	Indexed user input
# Menu Navigation	while True, if/elif
# Error Handling	try/except
# State Tracking (optional)	Boolean flags
#
#
#
# ⸻
#
# Let me know if you want help sketching out the structure in comments or if you’d like an example of how to use try/except with student input!
