# %% [markdown]
# # ChatGPT Conversation

# %% [markdown]
# ## Input

# %% [markdown]
# Hi ChatGPT, I’m working on my Week 6 Instructor-led Lab for my graduate Python course (BGEN 632 - UM MSBA). The assignment is to create a Magic Crystal Ball program using arrays/lists, loops, and menu logic.
#
# I am not looking for final answers. I want help understanding how to approach the assignment step-by-step, especially using Boolean values to switch menu prompts, storing questions/responses in lists, and generating random responses from a list.
#
# Can you walk me through how I should structure the logic using pseudo-code or examples—without giving me the full solution? I’ll write my own code based on what I learn. Assignment: # Instructor-led Lab
#
# In this assignment you will practice utilizing arrays and/or lists in a program.
#
# ## Magic Crystal Ball
#
# You have decided your future does not lie in data science. Instead, you would like to ply your trade in fortune telling. As someone who has a solid understanding of technology, you decide to eschew a physical store and practice solely online. As such, you are keen on developing a program that will behave like a magic crystal ball.
#
# Based on your vast research into "magic crystal ball" fortune telling, you decide on the following responses:
#
# * It is certain
# * It is decidedly so
# * That question requires greater monetary compensation
# * Reply is hazy; try again, with more money
# * Concentrate and ask again
# * My reply is no
# * Outlook is not so good
# * Very doubtful
#
# In addition to these 8 responses, *you will also provide 3 more of your own*. Make sure your personality shows through *by not making them generic*. Save all of these responses in an array.
#
# Your program should do the following:
#
# 1. Prompt the user to "Ask a question," "Review questions and responses," and "Complete services and pay."
#    * If they already asked their first question, change the menu from "Ask *a* question" to "Ask *another* question." Keep track of this with a boolean.
# 2. Always provide the menu until the user decides to complete their use of the magic crystal ball.
# 3. Store the user's questions and received responses in an array/list. When the user selects the option "Review questions and responses" display all the questions asked and their respective answers to the screen.
# 4. **Randomly** select a response from your catalog of responses as a reply to the user's question (see below for guidance).
# 5. Keep track of how much the user owes for services. You charge $30.00 per question asked. Thus, when the user completes their use of your services, you will display the total owed and the count of the questions asked.
#
# When you run your program, please input **at least 4 questions**. Save your notebook with the output of your program showing that:
# * You have run the program and inputted at least 4 questions.
# * Selected the other menu options to display questions/responses and complete services.
#
# Here is an example of program output with 2 questions:
#
# ```
# Welcome to the all-seeing computer!
#
# 1. Ask a question
# 2. Review questions and responses
# 3. Complete services and pay
#
# 1
#
# Ask what you seek to know...
# Will I become a Python expert?
# It is decidely so.
#
# 1. Ask another question
# 2. Review questions and responses
# 3. Complete services and pay
#
# 1
#
# Ask what you seek to know...
# Should I have Wally & Buck for dinner?
# Reply is hazy; try again, with more money.
#
# 1. Ask another question
# 2. Review questions and responses
# 3. Complete services and pay
#
# 2
#
# Question: "Will I become a Python expert?"
# Response: "It is decidely so."
#
# Question: "Should I have Wally & Buck for dinner?"
# Response: "Reply is hazy; try again, with more money."
#
# 1. Ask another question
# 2. Review questions and responses
# 3. Complete services and pay
#
# 3
#
# Thank you for visiting the all-seeing computer.
#
# You asked 2 questions. You owe $60.00 for today's services.
#
# ```
#
# ### Randomness in Programming
#
# For this assignment, you will need to use a random number generator. Specifically, you will need to generate a random number within the range of your list's elements. A range is used in order to constrain the generated number to fit within the bounds of the number of elements within your list. To do so, you can rely on the library `random`. Here is an example with a list containing cities in Montana.
#
# ```Python
# import random as rand
#
# some_list = ['Missoula','Hamilton','Stevensville','Lolo']
#
# rand_a = rand.randrange(0, len(some_list))
#
# some_list[rand_a]
# ```
#
# As an alternative, you can generate a random selection from a list using the function `choice()`. This is the preferred method for lists, arrays, and dictionaries.
#
# ```Python
# rand_b = rand.choice(some_list)
# ```

# %% [markdown]
# ## Output

# %% [markdown]
# Hey Michelle, awesome job breaking this down so clearly! You’re already thinking the right way by wanting to understand the logic before diving into the code. Let’s go step-by-step and build a solid game plan using pseudocode and structure ideas—without giving you a full solution, of course.
#
# ⸻
#
# 🔧 Step-by-Step Logic Breakdown
#
# ⸻
#
# 1. Set Up Your Crystal Ball Responses
#
# Store the 8 given responses plus 3 personal ones in a list. This list won’t change, so it’s a good candidate for a constant at the top of your code.
#
# responses = ["It is certain", "It is decidedly so", ..., "Your custom #3"]
#
#
#
# ⸻
#
# 2. Initialize Key Variables
#
# You’ll need a few key variables:
# 	•	questions → an empty list to store what the user asks
# 	•	answers → a parallel list to store which response was given
# 	•	question_count → to track how many questions were asked (or just use len(questions))
# 	•	total_due → starts at $0
# 	•	asked_first_question → a Boolean flag that starts as False
#
# ⸻
#
# 3. Start the Main Loop
#
# Use a while True: loop to repeatedly show the menu until the user chooses to exit.
#
# Pseudocode:
#
# while True:
#     if asked_first_question:
#         display "1. Ask another question"
#     else:
#         display "1. Ask a question"
#
#     display "2. Review questions and responses"
#     display "3. Complete services and pay"
#
#     get user input
#
#     if input == 1:
#         prompt user for a question
#         randomly choose a response from responses list
#         append question to questions list
#         append response to answers list
#         set asked_first_question = True
#         increment total_due by $30
#
#     elif input == 2:
#         for each question and matching response:
#             display them
#
#     elif input == 3:
#         break the loop
#     else:
#         print "Invalid option"
#
#
#
# ⸻
#
# 4. Use Random to Select a Response
#
# When the user inputs a question, use:
#
# import random
# response = random.choice(responses)
#
#
#
# ⸻
#
# 5. Track Payment
#
# Every question = $30. So just:
#
# total_due = len(questions) * 30
#
#
#
# ⸻
#
# 6. End the Program Gracefully
#
# When they select option 3:
# 	•	Display thank-you message
# 	•	Show total number of questions asked
# 	•	Show total due
#
# ⸻
#
# ⚠️ Edge Cases to Watch For
# 	•	What if they try to review questions before asking any? Prevent errors with an if not questions: check.
# 	•	Input validation: Ensure only 1, 2, or 3 are valid choices.
#
# ⸻
#
# 🧠 Mental Map
#
# Think of the program like a loop-driven menu interface with three key behaviors:
# 	•	Add to two lists (questions[] and answers[])
# 	•	Retrieve/display paired list content
# 	•	Calculate cost dynamically from list length
#
# You’re managing state with the asked_first_question Boolean and letting that control what the menu says, but not how it works behind the scenes.
#
# ⸻
#
# Let me know if you want a walkthrough of how to use zip() for showing questions + answers or if you’d like help drafting test cases or a flowchart for planning!
